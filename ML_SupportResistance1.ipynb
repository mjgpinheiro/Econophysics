# %% [markdown]
# <a href="https://colab.research.google.com/github/mjgpinheiro/Econophysics/blob/main/ML_SupportResistance1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import numpy as np
import yfinance as yf
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load AAPL stock data
data = yf.download('AAPL', start='2019-01-01', end='2023-03-26')
prices = data['Close'].to_numpy()

# Calculate support and resistance levels
n_days = len(prices)
pct_change = (prices[1:] - prices[:-1])/prices[:-1]
avg_change = np.mean(pct_change)
std_change = np.std(pct_change)
s1 = prices[-1] - 2*std_change*prices[-1]
s2 = prices[-1] - std_change*prices[-1]
s3 = prices[-1] - avg_change*prices[-1]
r1 = prices[-1] + 2*std_change*prices[-1]
r2 = prices[-1] + std_change*prices[-1]
r3 = prices[-1] + avg_change*prices[-1]

# Define function to generate features
def generate_features(prices, s1, s2, s3, r1, r2, r3):
    pct_change = (prices[1:] - prices[:-1])/prices[:-1]
    features = []
    for i in range(1, len(prices)):
        feature = []
        if prices[i-1] < s1:
            feature.append(0)
        elif s1 <= prices[i-1] < s2:
            feature.append(1)
        elif s2 <= prices[i-1] < s3:
            feature.append(2)
        elif s3 <= prices[i-1] < r3:
            feature.append(3)
        elif r3 <= prices[i-1] < r2:
            feature.append(4)
        elif r2 <= prices[i-1] < r1:
            feature.append(5)
        else:
            feature.append(6)
        features.append(feature)
    return features

# Generate features and labels
features = generate_features(prices, s1, s2, s3, r1, r2, r3)
labels = []
for i in range(1, len(prices)):
    if prices[i] > prices[i-1]:
        labels.append(1)
    else:
        labels.append(0)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2)

# Train a random forest classifier on the training set
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = clf.predict(X_test)

# Evaluate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Predict buy, sell, or hold outcome for AAPL stock price over the past week
data = yf.download('AAPL', start='2022-03-16', end='2023-03-26')
prices = data['Close'].to_numpy()
features = generate_features(prices, s1, s2, s3, r1, r2, r3)
outcome_probs = clf.predict_proba(features)[:, 1]

# Convert the outcome probabilities to "buy", "sell", or "hold"
THRESHOLD_BUY = 0.6
THRESHOLD_SELL = 0.4

predictions = []
for prob in outcome_probs:
    if prob >= THRESHOLD_BUY:
        predictions.append("buy")
    elif prob <= THRESHOLD_SELL:
        predictions.append("sell")
    else:
        predictions.append("hold")

for i in range(len(predictions)):
    print(f"Prediction for day {i+1}: {predictions[i]}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Accuracy: 0.5352112676056338
# [*********************100%***********************]  1 of 1 completed
# Prediction for day 1: buy
# Prediction for day 2: sell
# Prediction for day 3: sell
# Prediction for day 4: sell
# Prediction for day 5: hold
# Prediction for day 6: hold
# Prediction for day 7: hold
# Prediction for day 8: hold
# Prediction for day 9: hold
# Prediction for day 10: hold
# Prediction for day 11: hold
# Prediction for day 12: hold
# Prediction for day 13: hold
# Prediction for day 14: hold
# Prediction for day 15: hold
# Prediction for day 16: hold
# Prediction for day 17: hold
# Prediction for day 18: hold
# Prediction for day 19: sell
# Prediction for day 20: hold
# Prediction for day 21: hold
# Prediction for day 22: sell
# Prediction for day 23: sell
# Prediction for day 24: hold
# Prediction for day 25: hold
# Prediction for day 26: sell
# Prediction for day 27: sell
# Prediction for day 28: sell
# Prediction for day 29: sell
# Prediction for day 30: sell
# Prediction for day 31: sell
# Prediction for day 32: buy
# Prediction for day 33: buy
# Prediction for day 34: buy
# Prediction for day 35: sell
# Prediction for day 36: sell
# Prediction for day 37: buy
# Prediction for day 38: hold
# Prediction for day 39: sell
# Prediction for day 40: hold
# Prediction for day 41: hold
# Prediction for day 42: hold
# Prediction for day 43: hold
# Prediction for day 44: hold
# Prediction for day 45: hold
# Prediction for day 46: hold
# Prediction for day 47: hold
# Prediction for day 48: hold
# Prediction for day 49: hold
# Prediction for day 50: hold
# Prediction for day 51: hold
# Prediction for day 52: hold
# Prediction for day 53: hold
# Prediction for day 54: hold
# Prediction for day 55: hold
# Prediction for day 56: hold
# Prediction for day 57: hold
# Prediction for day 58: hold
# Prediction for day 59: hold
# Prediction for day 60: hold
# Prediction for day 61: hold
# Prediction for day 62: hold
# Prediction for day 63: hold
# Prediction for day 64: hold
# Prediction for day 65: hold
# Prediction for day 66: hold
# Prediction for day 67: hold
# Prediction for day 68: hold
# Prediction for day 69: hold
# Prediction for day 70: hold
# Prediction for day 71: hold
# Prediction for day 72: hold
# Prediction for day 73: hold
# Prediction for day 74: hold
# Prediction for day 75: hold
# Prediction for day 76: hold
# Prediction for day 77: hold
# Prediction for day 78: hold
# Prediction for day 79: hold
# Prediction for day 80: hold
# Prediction for day 81: hold
# Prediction for day 82: hold
# Prediction for day 83: hold
# Prediction for day 84: hold
# Prediction for day 85: hold
# Prediction for day 86: hold
# Prediction for day 87: hold
# Prediction for day 88: sell
# Prediction for day 89: sell
# Prediction for day 90: hold
# Prediction for day 91: hold
# Prediction for day 92: sell
# Prediction for day 93: buy
# Prediction for day 94: sell
# Prediction for day 95: sell
# Prediction for day 96: buy
# Prediction for day 97: sell
# Prediction for day 98: sell
# Prediction for day 99: sell
# Prediction for day 100: sell
# Prediction for day 101: sell
# Prediction for day 102: hold
# Prediction for day 103: hold
# Prediction for day 104: hold
# Prediction for day 105: hold
# Prediction for day 106: hold
# Prediction for day 107: hold
# Prediction for day 108: hold
# Prediction for day 109: hold
# Prediction for day 110: hold
# Prediction for day 111: hold
# Prediction for day 112: hold
# Prediction for day 113: hold
# Prediction for day 114: sell
# Prediction for day 115: sell
# Prediction for day 116: buy
# Prediction for day 117: buy
# Prediction for day 118: buy
# Prediction for day 119: sell
# Prediction for day 120: sell
# Prediction for day 121: sell
# Prediction for day 122: sell
# Prediction for day 123: buy
# Prediction for day 124: sell
# Prediction for day 125: sell
# Prediction for day 126: sell
# Prediction for day 127: hold
# Prediction for day 128: hold
# Prediction for day 129: sell
# Prediction for day 130: buy
# Prediction for day 131: sell
# Prediction for day 132: hold
# Prediction for day 133: hold
# Prediction for day 134: hold
# Prediction for day 135: hold
# Prediction for day 136: hold
# Prediction for day 137: hold
# Prediction for day 138: hold
# Prediction for day 139: hold
# Prediction for day 140: hold
# Prediction for day 141: hold
# Prediction for day 142: hold
# Prediction for day 143: hold
# Prediction for day 144: hold
# Prediction for day 145: hold
# Prediction for day 146: hold
# Prediction for day 147: hold
# Prediction for day 148: hold
# Prediction for day 149: hold
# Prediction for day 150: hold
# Prediction for day 151: hold
# Prediction for day 152: hold
# Prediction for day 153: hold
# Prediction for day 154: hold
# Prediction for day 155: hold
# Prediction for day 156: hold
# Prediction for day 157: hold
# Prediction for day 158: sell
# Prediction for day 159: hold
# Prediction for day 160: hold
# Prediction for day 161: hold
# Prediction for day 162: hold
# Prediction for day 163: hold
# Prediction for day 164: hold
# Prediction for day 165: hold
# Prediction for day 166: hold
# Prediction for day 167: hold
# Prediction for day 168: hold
# Prediction for day 169: hold
# Prediction for day 170: hold
# Prediction for day 171: hold
# Prediction for day 172: hold
# Prediction for day 173: hold
# Prediction for day 174: hold
# Prediction for day 175: hold
# Prediction for day 176: hold
# Prediction for day 177: hold
# Prediction for day 178: hold
# Prediction for day 179: hold
# Prediction for day 180: hold
# Prediction for day 181: hold
# Prediction for day 182: hold
# Prediction for day 183: hold
# Prediction for day 184: hold
# Prediction for day 185: hold
# Prediction for day 186: hold
# Prediction for day 187: hold
# Prediction for day 188: hold
# Prediction for day 189: hold
# Prediction for day 190: hold
# Prediction for day 191: hold
# Prediction for day 192: hold
# Prediction for day 193: hold
# Prediction for day 194: hold
# Prediction for day 195: hold
# Prediction for day 196: hold
# Prediction for day 197: hold
# Prediction for day 198: hold
# Prediction for day 199: hold
# Prediction for day 200: hold
# Prediction for day 201: hold
# Prediction for day 202: hold
# Prediction for day 203: hold
# Prediction for day 204: hold
# Prediction for day 205: hold
# Prediction for day 206: hold
# Prediction for day 207: hold
# Prediction for day 208: hold
# Prediction for day 209: hold
# Prediction for day 210: hold
# Prediction for day 211: hold
# Prediction for day 212: hold
# Prediction for day 213: hold
# Prediction for day 214: hold
# Prediction for day 215: hold
# Prediction for day 216: hold
# Prediction for day 217: hold
# Prediction for day 218: hold
# Prediction for day 219: hold
# Prediction for day 220: hold
# Prediction for day 221: hold
# Prediction for day 222: hold
# Prediction for day 223: hold
# Prediction for day 224: sell
# Prediction for day 225: hold
# Prediction for day 226: sell
# Prediction for day 227: hold
# Prediction for day 228: hold
# Prediction for day 229: hold
# Prediction for day 230: sell
# Prediction for day 231: hold
# Prediction for day 232: sell
# Prediction for day 233: sell
# Prediction for day 234: hold
# Prediction for day 235: hold
# Prediction for day 236: hold
# Prediction for day 237: hold
# Prediction for day 238: hold
# Prediction for day 239: hold
# Prediction for day 240: hold
# Prediction for day 241: hold
# Prediction for day 242: hold
# Prediction for day 243: hold
# Prediction for day 244: sell
# Prediction for day 245: hold
# Prediction for day 246: hold
# Prediction for day 247: hold
# Prediction for day 248: hold
# Prediction for day 249: hold
# Prediction for day 250: hold
# Prediction for day 251: hold
# Prediction for day 252: sell
# Prediction for day 253: sell
# Prediction for day 254: buy
# Prediction for day 255: buy
# Prediction for day 256: buy
# Prediction for day 257: buy
