# %% [markdown]
# <a href="https://colab.research.google.com/github/mjgpinheiro/Econophysics/blob/main/Money_Tensor_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install stable-baselines3
# !pip install shimmy
# !pip install gymnasium

# Import necessary libraries
import gym
from gym import spaces
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Define the Economic Environment with the refined reward function
class EconomicEnvironment(gym.Env):
    def __init__(self):
        super(EconomicEnvironment, self).__init__()
        # State: [GDP Growth, Sectoral Productivity, Inflation, Unemployment, Trade Balance, Resistance]
        self.state = np.array([3.0, 100.0, 5.0, 8.0, 0.0, 0.5])  # Initial state
        self.previous_action = np.array([0.0, 0.0, 0.0])  # Previous action for fluctuation penalties
        self.action_space = spaces.Box(low=-1, high=1, shape=(3,), dtype=np.float32)  # Policy actions
        self.observation_space = spaces.Box(
            low=np.array([0.0, 50.0, 0.0, 0.0, -500.0, 0.0]),
            high=np.array([5.0, 200.0, 10.0, 15.0, 500.0, 1.0]),
            dtype=np.float32,
        )
        self.step_count = 0
        self.max_steps = 100  # Episode length

    def step(self, action):
        # Apply policy actions: [spending, tax cuts, subsidies]
        spending, tax_cut, subsidy = action

        # Update state based on actions
        gdp_growth = self.state[0] + 0.1 * spending - 0.05 * self.state[5]
        resistance = self.state[5] - 0.1 * (spending + subsidy) + 0.05 * tax_cut
        inflation = self.state[2] + 0.05 * spending - 0.02 * subsidy
        unemployment = self.state[3] - 0.1 * subsidy + 0.02 * spending
        trade_balance = self.state[4] + 0.1 * (spending - subsidy)

        # Clamp values within bounds
        gdp_growth = np.clip(gdp_growth, 0.0, 5.0)
        resistance = np.clip(resistance, 0.0, 1.0)
        inflation = np.clip(inflation, 0.0, 10.0)
        unemployment = np.clip(unemployment, 0.0, 15.0)
        trade_balance = np.clip(trade_balance, -500.0, 500.0)

        # Update the state
        self.state = np.array([gdp_growth, self.state[1], inflation, unemployment, trade_balance, resistance])
        self.step_count += 1

        # Refined Reward Function
        reward = (
            2.5 * gdp_growth                  # Increased reward for GDP growth
            - 3.0 * inflation                 # Stronger penalty for inflation
            - 1.5 * resistance                # Penalty for resistance
            - 0.8 * unemployment              # Higher penalty for unemployment
            - 0.7 * abs(trade_balance / 500)  # Stronger penalty for trade deficits (normalized)
            - 0.2 * (spending**2 + tax_cut**2 + subsidy**2)  # Penalty for excessive actions
            - 0.4 * abs(spending - subsidy)  # Penalize imbalance between spending and subsidies
            - 0.3 * (np.abs(spending - self.previous_action[0])**2)  # Exponential penalty for rapid spending changes
            - 0.3 * (np.abs(tax_cut - self.previous_action[1])**2)   # Exponential penalty for rapid tax cut changes
            - 0.3 * (np.abs(subsidy - self.previous_action[2])**2)   # Exponential penalty for rapid subsidy changes
        )

        # Save current action for fluctuation penalty in the next step
        self.previous_action = action

        done = self.step_count >= self.max_steps
        return self.state, reward, done, {}

    def reset(self):
        # Reset state
        self.state = np.array([3.0, 100.0, 5.0, 8.0, 0.0, 0.5])
        self.previous_action = np.array([0.0, 0.0, 0.0])  # Initialize previous action for fluctuation penalties
        self.step_count = 0
        return self.state

    def render(self, mode="human"):
        print(f"State: {self.state}")


# Create the environment
env = EconomicEnvironment()
vec_env = make_vec_env(lambda: env, n_envs=1)

# Train the PPO Agent with the refined environment
model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=150000)  # Train for 150,000 timesteps
model.save("ppo_economic_policy_refined_v7")
trained_model = PPO.load("ppo_economic_policy_refined_v7")


# Function to Simulate Shocks and Test the Agent
def simulate_shocks(env, shock_type):
    print(f"\nSimulating Shock: {shock_type}")

    # Apply specific shock to the initial state
    if shock_type == "Inflation Surge":
        env.state[2] = 9.0  # Set inflation to a high value (9%)
    elif shock_type == "Trade Deficit":
        env.state[4] = -400.0  # Set trade balance to a large deficit (-400B)
    elif shock_type == "High Unemployment":
        env.state[3] = 14.0  # Set unemployment rate to a high value (14%)

    # Reset step count
    env.step_count = 0

    # Simulate the agent's response to the shock
    state = env.state
    done = False
    total_reward = 0
    states = []
    actions = []

    while not done:
        action, _ = trained_model.predict(state)
        next_state, reward, done, _ = env.step(action)
        total_reward += reward

        # Record states and actions
        states.append(state)
        actions.append(action)

        # Update the state
        state = next_state

    # Convert states and actions to arrays
    states = np.array(states)
    actions = np.array(actions)

    return states, actions, total_reward


# Test the agent under different shocks
shocks = ["Inflation Surge", "Trade Deficit", "High Unemployment"]

for shock in shocks:
    states, actions, total_reward = simulate_shocks(env, shock)

    # Visualize results
    time_steps = range(len(states))

    plt.figure(figsize=(16, 8))

    # GDP Growth
    plt.subplot(2, 3, 1)
    plt.plot(time_steps, states[:, 0], label="GDP Growth", color='green')
    plt.title(f"GDP Growth Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("GDP Growth (%)")
    plt.grid()

    # Inflation
    plt.subplot(2, 3, 2)
    plt.plot(time_steps, states[:, 2], label="Inflation", color='orange')
    plt.title(f"Inflation Rate Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Inflation (%)")
    plt.grid()

    # Unemployment
    plt.subplot(2, 3, 3)
    plt.plot(time_steps, states[:, 3], label="Unemployment", color='purple')
    plt.title(f"Unemployment Rate Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Unemployment (%)")
    plt.grid()

    # Trade Balance
    plt.subplot(2, 3, 4)
    plt.plot(time_steps, states[:, 4], label="Trade Balance", color='blue')
    plt.title(f"Trade Balance Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Trade Balance (Billion $)")
    plt.grid()

    # Resistance
    plt.subplot(2, 3, 5)
    plt.plot(time_steps, states[:, 5], label="Resistance", color='red')
    plt.title(f"Economic Resistance Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Resistance")
    plt.grid()

    # Agent Actions
    plt.subplot(2, 3, 6)
    plt.plot(time_steps, actions[:, 0], label="Spending", color='green')
    plt.plot(time_steps, actions[:, 1], label="Tax Cuts", color='blue')
    plt.plot(time_steps, actions[:, 2], label="Subsidies", color='orange')
    plt.title(f"Agent Actions Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Action Values")
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

    print(f"Total Reward Under {shock}: {total_reward:.2f}")
########
# Additional scenarios
additional_shocks = [
    "Deflationary Shock",
    "High Trade Surplus",
    "Stagflation",
    "Rapid Economic Boom"
]

# Combined list of all scenarios
all_shocks = shocks + additional_shocks

# Simulate all scenarios
for shock in all_shocks:
    # Apply specific shock to the environment's initial state
    if shock == "Deflationary Shock":
        env.state[2] = 0.5  # Set inflation to very low (0.5%)
    elif shock == "High Trade Surplus":
        env.state[4] = 400.0  # Set trade balance to high surplus (+400B)
    elif shock == "Stagflation":
        env.state[3] = 12.0  # High unemployment (12%)
        env.state[2] = 8.0   # High inflation (8%)
    elif shock == "Rapid Economic Boom":
        env.state[0] = 5.0  # High GDP growth (5%)
        env.state[2] = 8.0  # High inflation (8%)
    else:
        # Default shocks already defined
        pass

    # Reset step count
    env.step_count = 0

    # Simulate the agent's response to the shock
    states, actions, total_reward = simulate_shocks(env, shock)

    # Visualize results
    time_steps = range(len(states))

    plt.figure(figsize=(16, 8))

    # GDP Growth
    plt.subplot(2, 3, 1)
    plt.plot(time_steps, states[:, 0], label="GDP Growth", color='green')
    plt.title(f"GDP Growth Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("GDP Growth (%)")
    plt.grid()

    # Inflation
    plt.subplot(2, 3, 2)
    plt.plot(time_steps, states[:, 2], label="Inflation", color='orange')
    plt.title(f"Inflation Rate Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Inflation (%)")
    plt.grid()

    # Unemployment
    plt.subplot(2, 3, 3)
    plt.plot(time_steps, states[:, 3], label="Unemployment", color='purple')
    plt.title(f"Unemployment Rate Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Unemployment (%)")
    plt.grid()

    # Trade Balance
    plt.subplot(2, 3, 4)
    plt.plot(time_steps, states[:, 4], label="Trade Balance", color='blue')
    plt.title(f"Trade Balance Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Trade Balance (Billion $)")
    plt.grid()

    # Resistance
    plt.subplot(2, 3, 5)
    plt.plot(time_steps, states[:, 5], label="Resistance", color='red')
    plt.title(f"Economic Resistance Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Resistance")
    plt.grid()

    # Agent Actions
    plt.subplot(2, 3, 6)
    plt.plot(time_steps, actions[:, 0], label="Spending", color='green')
    plt.plot(time_steps, actions[:, 1], label="Tax Cuts", color='blue')
    plt.plot(time_steps, actions[:, 2], label="Subsidies", color='orange')
    plt.title(f"Agent Actions Under {shock}")
    plt.xlabel("Timestep")
    plt.ylabel("Action Values")
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

    print(f"Total Reward Under {shock}: {total_reward:.2f}")
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.5.0
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from shimmy) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.11/dist-packages (from shimmy) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# /usr/local/lib/python3.11/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# /usr/local/lib/python3.11/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -1.9e+03 |
# | time/              |          |
# |    fps             | 1327     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.85e+03   |
# | time/                   |             |
# |    fps                  | 998         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008154933 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 7.03e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.63e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00653    |
# |    std                  | 0.99        |
# |    value_loss           | 7.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.77e+03   |
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006422908 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 2.65e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.59e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00368    |
# |    std                  | 0.975       |
# |    value_loss           | 6.7e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.7e+03    |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004324592 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 2.38e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.66e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00336    |
# |    std                  | 0.966       |
# |    value_loss           | 5.21e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.64e+03    |
# | time/                   |              |
# |    fps                  | 802          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0035827726 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 2.03e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00264     |
# |    std                  | 0.961        |
# |    value_loss           | 4.44e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.54e+03    |
# | time/                   |              |
# |    fps                  | 803          |
# |    iterations           | 6            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0054406687 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.13        |
# |    explained_variance   | 1.25e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.91e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00353     |
# |    std                  | 0.958        |
# |    value_loss           | 3.77e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.45e+03   |
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006980853 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 7.15e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00706    |
# |    std                  | 0.952       |
# |    value_loss           | 3.76e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.38e+03    |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 8            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0050113313 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.1         |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.946        |
# |    value_loss           | 3.31e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.34e+03    |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 9            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0036524367 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.06        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00255     |
# |    std                  | 0.932        |
# |    value_loss           | 2.87e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.31e+03    |
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 10           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0033552258 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.04        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000907     |
# |    std                  | 0.927        |
# |    value_loss           | 2.73e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.28e+03    |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 11           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0046337256 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4           |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+04     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00421     |
# |    std                  | 0.909        |
# |    value_loss           | 2.74e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.26e+03   |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 12          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006259871 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00413    |
# |    std                  | 0.907       |
# |    value_loss           | 2.69e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.23e+03    |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 13           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0055162935 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.95        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+04     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00423     |
# |    std                  | 0.899        |
# |    value_loss           | 2.59e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 14           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0050740344 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.92        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.64e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000113    |
# |    std                  | 0.887        |
# |    value_loss           | 2.09e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.18e+03   |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 15          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.003930835 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000713   |
# |    std                  | 0.895       |
# |    value_loss           | 2.1e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 16           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0036757644 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.91        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00197     |
# |    std                  | 0.891        |
# |    value_loss           | 2.06e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 17           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0035560126 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.89        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.04e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.883        |
# |    value_loss           | 1.96e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 18           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0032035955 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.86        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.98e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.873        |
# |    value_loss           | 1.94e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 19           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0043849195 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.84        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+04     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00171     |
# |    std                  | 0.868        |
# |    value_loss           | 1.91e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 765          |
# |    iterations           | 20           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0047857976 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.84        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.79e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 0.871        |
# |    value_loss           | 1.76e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 767          |
# |    iterations           | 21           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0049902303 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.84        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.26e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.869        |
# |    value_loss           | 1.64e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.09e+03  |
# | time/                   |            |
# |    fps                  | 769        |
# |    iterations           | 22         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00738186 |
# |    clip_fraction        | 0.0928     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.83      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.05e+03   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00658   |
# |    std                  | 0.866      |
# |    value_loss           | 1.89e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 23           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0029744967 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.83        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.26e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000586    |
# |    std                  | 0.866        |
# |    value_loss           | 1.57e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 769          |
# |    iterations           | 24           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0058879857 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.8         |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.22e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.005       |
# |    std                  | 0.852        |
# |    value_loss           | 1.41e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.03e+03   |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 25          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007825958 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.16e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00677    |
# |    std                  | 0.837       |
# |    value_loss           | 1.46e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -997         |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 26           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0065026344 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.7         |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.58e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0045      |
# |    std                  | 0.826        |
# |    value_loss           | 1.32e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -980        |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 27          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006208376 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.18e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00347    |
# |    std                  | 0.827       |
# |    value_loss           | 1.31e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -969        |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 28          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.006711393 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.16e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 0.813       |
# |    value_loss           | 1.23e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -957        |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 29          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.002561983 |
# |    clip_fraction        | 0.0233      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.28e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.000408    |
# |    std                  | 0.81        |
# |    value_loss           | 1.2e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -948         |
# | time/                   |              |
# |    fps                  | 762          |
# |    iterations           | 30           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0025021438 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.62        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.33e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000276     |
# |    std                  | 0.808        |
# |    value_loss           | 1.17e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -944        |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 31          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005923024 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 3.87e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.41e+03    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00424    |
# |    std                  | 0.81        |
# |    value_loss           | 1.19e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -941         |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 32           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0055661164 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.62        |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.18e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00206     |
# |    std                  | 0.81         |
# |    value_loss           | 1.07e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -930         |
# | time/                   |              |
# |    fps                  | 767          |
# |    iterations           | 33           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0042909617 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.62        |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.45e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00172     |
# |    std                  | 0.809        |
# |    value_loss           | 9.29e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -914         |
# | time/                   |              |
# |    fps                  | 762          |
# |    iterations           | 34           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0048107915 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.62        |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.05e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000506    |
# |    std                  | 0.809        |
# |    value_loss           | 7.9e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -906         |
# | time/                   |              |
# |    fps                  | 762          |
# |    iterations           | 35           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0030220943 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.61        |
# |    explained_variance   | 0.655        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.87e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00136     |
# |    std                  | 0.805        |
# |    value_loss           | 7.43e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -888        |
# | time/                   |             |
# |    fps                  | 763         |
# |    iterations           | 36          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005834417 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00451    |
# |    std                  | 0.804       |
# |    value_loss           | 7.73e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -874         |
# | time/                   |              |
# |    fps                  | 764          |
# |    iterations           | 37           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0045235967 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.58        |
# |    explained_variance   | 0.699        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.83e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0032      |
# |    std                  | 0.794        |
# |    value_loss           | 6.99e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -868         |
# | time/                   |              |
# |    fps                  | 765          |
# |    iterations           | 38           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0034486009 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.55        |
# |    explained_variance   | 0.706        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.19e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 0.789        |
# |    value_loss           | 6.54e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -860         |
# | time/                   |              |
# |    fps                  | 760          |
# ...
# |    policy_gradient_loss | -0.000747   |
# |    std                  | 0.757       |
# |    value_loss           | 3.21e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -776         |
# | time/                   |              |
# |    fps                  | 755          |
# |    iterations           | 59           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0046867467 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.42        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 982          |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00332     |
# |    std                  | 0.76         |
# |    value_loss           | 2.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -772         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 60           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0035559693 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.42        |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+03      |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000834    |
# |    std                  | 0.756        |
# |    value_loss           | 2.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -778         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 61           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0023789045 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.4         |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+03     |
# |    n_updates            | 600          |
# |    policy_gradient_loss | 0.00135      |
# |    std                  | 0.751        |
# |    value_loss           | 2.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -775         |
# | time/                   |              |
# |    fps                  | 758          |
# |    iterations           | 62           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0067621516 |
# |    clip_fraction        | 0.0882       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.39        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+03     |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00534     |
# |    std                  | 0.749        |
# |    value_loss           | 2.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -776        |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 63          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.005036557 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 649         |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00236    |
# |    std                  | 0.738       |
# |    value_loss           | 2.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -774        |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 64          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004688289 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 801         |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00486    |
# |    std                  | 0.739       |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -773         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 65           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 133120       |
# | train/                  |              |
# |    approx_kl            | 0.0073256213 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.34        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 0.738        |
# |    value_loss           | 2.24e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -770        |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 66          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.007277957 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 807         |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.00238    |
# |    std                  | 0.724       |
# |    value_loss           | 2.11e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -767         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 67           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 137216       |
# | train/                  |              |
# |    approx_kl            | 0.0028531938 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.28        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 643          |
# |    n_updates            | 660          |
# |    policy_gradient_loss | 7.03e-05     |
# |    std                  | 0.724        |
# |    value_loss           | 1.96e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -765        |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 68          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.004201689 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 864         |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00243    |
# |    std                  | 0.727       |
# |    value_loss           | 1.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -765        |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 69          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.006254128 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 562         |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.00314    |
# |    std                  | 0.725       |
# |    value_loss           | 1.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -765        |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 70          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.003427249 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 622         |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.000753   |
# |    std                  | 0.723       |
# |    value_loss           | 1.76e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -762         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 71           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 145408       |
# | train/                  |              |
# |    approx_kl            | 0.0070030317 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 491          |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.00361     |
# |    std                  | 0.718        |
# |    value_loss           | 1.67e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -759        |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 72          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.003590115 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 540         |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.000975   |
# |    std                  | 0.71        |
# |    value_loss           | 1.46e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -756         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 73           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0046499684 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.21        |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 756          |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.000437    |
# |    std                  | 0.703        |
# |    value_loss           | 1.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -752         |
# | time/                   |              |
# |    fps                  | 754          |
# |    iterations           | 74           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0062818895 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 486          |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.00248     |
# |    std                  | 0.702        |
# |    value_loss           | 1.23e+03     |
# ------------------------------------------
#
# Simulating Shock: Inflation Surge
# Total Reward Under Inflation Surge: -1403.17
#
# Simulating Shock: Trade Deficit
# Total Reward Under Trade Deficit: -1149.37
#
# Simulating Shock: High Unemployment
# Total Reward Under High Unemployment: -2560.98
#
# Simulating Shock: Inflation Surge
# Total Reward Under Inflation Surge: -3418.40
#
# Simulating Shock: Trade Deficit
# Total Reward Under Trade Deficit: -2800.51
#
# Simulating Shock: High Unemployment
# Total Reward Under High Unemployment: -3040.83
#
# Simulating Shock: Deflationary Shock
# Total Reward Under Deflationary Shock: -768.64
#
# Simulating Shock: High Trade Surplus
# Total Reward Under High Trade Surplus: -659.63
#
# Simulating Shock: Stagflation
# Total Reward Under Stagflation: -3197.51
#
# Simulating Shock: Rapid Economic Boom
# Total Reward Under Rapid Economic Boom: -2381.44
