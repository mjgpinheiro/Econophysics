# %% [markdown]
# <a href="https://colab.research.google.com/github/mjgpinheiro/Econophysics/blob/main/ML_Prophet_Stocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor
import ta
from prophet import Prophet
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Lasso


# Download data
data = yf.download('AAPL', start='2016-01-01', end='2023-03-26')
if data.empty:
    raise ValueError("No data found for the specified dates.")
prices = data['Close'].to_numpy()

# Add technical indicators
rsi = ta.momentum.RSIIndicator(data['Close'], window=14)
data['RSI'] = rsi.rsi()

stoch = ta.momentum.StochasticOscillator(high=data['High'], low=data['Low'], close=data['Close'], window=14, smooth_window=3)
data['%K'] = stoch.stoch()


def predict(prices):
    # Split data into training and testing sets
    train_prices = prices[:-365]
    test_prices = prices[-365:]
    if len(train_prices) < 5:
        return ["hold"] * len(test_prices), 0
    print(train_prices,test_prices)

    # Scale the data
    scaler = StandardScaler()
    X_train = scaler.fit_transform(train_prices.reshape(-1, 1))

    # Add RSI and Stochastic Oscillator to training data
    train_rsi = data['RSI'][:-365].to_numpy().reshape(-1, 1)
    train_k_percent = data['%K'][:-365].to_numpy().reshape(-1, 1)
    X_train = np.concatenate((X_train, train_rsi, train_k_percent), axis=1)

    # Use grid search to find the best hyperparameters
    if len(train_prices) >= 5:
        param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10]}
        # Impute missing values with the mean
        imputer = SimpleImputer(strategy='mean')
        X_train = imputer.fit_transform(X_train)

        grid_search = GridSearchCV(Lasso(), param_grid, cv=5)
        grid_search.fit(X_train[:-1], X_train[1:])
        best_alpha = grid_search.best_params_['alpha']
    else:
        best_alpha = 0.001

    # Train the model
    model = Sequential()
    model.add(LSTM(128, input_shape=(1, 3)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(X_train[:-1].reshape(-1, 1, 3), X_train[1:], epochs=50, batch_size=1, verbose=0)

    # Make prediction with LSTM model
    X_test = scaler.transform(test_prices.reshape(-1, 1))
#    test_rsi = data['RSI'][-365:].to_numpy().reshape(-1, 1)
    test_rsi = data['RSI'][-365:].to_numpy().reshape(-1, 1)

    test_k_percent = data['%K'][-365:].to_numpy().reshape(-1, 1)
    X_test = np.concatenate((X_test, test_rsi, test_k_percent), axis=1)
    y_pred = model.predict(X_test.reshape(-1, 1, 3))
    y_pred = scaler.inverse_transform(y_pred).flatten()

    # Calculate average return
    daily_returns = np.diff(prices[-365:]) / prices[-365:-1]
    strategy_returns = np.diff(y_pred) / prices[-365:-1]
    avg_return = np.mean(strategy_returns)

    return y_pred, avg_return

# Predict with LSTM model
lstm_prices, lstm_avg_return = predict(prices)

# Combine predictions
combined_predictions = []
for i in range(len(lstm_prices)):
  if lstm_prices[i] == "buy":
     combined_predictions.append("buy")
  elif lstm_prices[i] == "sell":
     combined_predictions.append("sell")
  else:
     prophet_change = prophet_prices[i] - prophet_prices[i-1]
     lstm_change = prices[-365+i+1] - prices[-365+i]
     if prophet_change > 0 and lstm_change > 0:
       combined_predictions.append("buy")
     elif prophet_change < 0 and lstm_change < 0:
       combined_predictions.append("sell")
     else:
       combined_predictions.append("hold")

# Calculate Sharpe ratio
prophet_prices = prophet_forecast['yhat'].tail(365).to_numpy()

daily_returns = np.diff(prices[-365:]) / prices[-365:-1]
strategy_returns = np.diff(prophet_prices) / prices[-365:-1]
sharpe_ratio = (np.mean(strategy_returns) - np.mean(daily_returns)) / np.std(daily_returns)


#Print trading strategy predictions
print("Trading strategy predictions:")
for i in range(len(combined_predictions)):
  print(f"Day {i+1}: {combined_predictions[i]}")
print(f"Sharpe ratio: {sharpe_ratio}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [ 26.33749962  25.67749977  25.17499924 ... 143.28999329 142.8999939
#  142.80999756] [141.50999451 140.91000366 143.75999451 144.83999634 146.55000305
#  148.75999451 149.25999451 149.47999573 148.69000244 148.63999939
#  149.32000732 148.8500061  152.57000732 149.80000305 148.96000671
#  150.02000427 151.49000549 150.96000671 151.27999878 150.44000244
#  150.80999756 147.91999817 147.86999512 149.99000549 150.
#  151.         153.49000549 157.86999512 160.55000305 161.02000427
#  161.41000366 161.94000244 156.80999756 160.24000549 165.30000305
#  164.77000427 163.75999451 161.83999634 165.32000732 171.17999268
#  175.08000183 174.55999756 179.44999695 175.74000549 174.33000183
#  179.30000305 172.25999451 171.13999939 169.75       172.99000549
#  175.63999939 176.27999878 180.33000183 179.28999329 179.38000488
#  178.19999695 177.57000732 182.00999451 179.69999695 174.91999817
#  172.         172.16999817 172.19000244 175.08000183 175.52999878
#  172.19000244 173.07000732 169.80000305 166.22999573 164.50999451
#  162.41000366 161.61999512 159.77999878 159.69000244 159.22000122
#  170.33000183 174.77999878 174.61000061 175.83999634 172.8999939
#  172.38999939 171.66000366 174.83000183 176.27999878 172.11999512
#  168.63999939 168.88000488 172.78999329 172.55000305 168.88000488
#  167.30000305 164.32000732 160.07000732 162.74000549 164.8500061
#  165.11999512 163.19999695 166.55999756 166.22999573 163.16999817
#  159.30000305 157.44000244 162.94999695 158.52000427 154.72999573
#  150.61999512 155.08999634 159.58999634 160.61999512 163.97999573
#  165.38000488 168.82000732 170.21000671 174.07000732 174.72000122
#  175.6000061  178.96000671 177.77000427 174.61000061 174.30999756
#  178.44000244 175.05999756 171.83000183 172.13999939 170.08999634
#  165.75       167.66000366 170.3999939  165.28999329 165.07000732
#  167.3999939  167.22999573 166.41999817 161.78999329 162.88000488
#  156.80000305 156.57000732 163.63999939 157.6499939  157.96000671
#  159.47999573 166.02000427 156.77000427 157.27999878 152.05999756
#  154.50999451 146.5        142.55999756 147.11000061 145.53999329
#  149.24000549 140.82000732 137.3500061  137.58999634 143.11000061
#  140.36000061 140.52000427 143.77999878 149.63999939 148.83999634
#  148.71000671 151.21000671 145.38000488 146.13999939 148.71000671
#  147.96000671 142.63999939 137.13000488 131.88000488 132.75999451
#  135.42999268 130.05999756 131.55999756 135.86999512 135.3500061
#  138.27000427 141.66000366 141.66000366 137.44000244 139.22999573
#  136.72000122 138.92999268 141.55999756 142.91999817 146.3500061
#  147.03999329 144.86999512 145.86000061 145.49000549 148.47000122
#  150.16999817 147.07000732 151.         153.03999329 155.3500061
#  154.08999634 152.94999695 151.6000061  156.78999329 157.3500061
#  162.50999451 161.50999451 160.00999451 166.13000488 165.80999756
#  165.3500061  164.86999512 164.91999817 169.24000549 168.49000549
#  172.1000061  173.19000244 173.02999878 174.55000305 174.1499939
#  171.52000427 167.57000732 167.22999573 167.52999878 170.02999878
#  163.61999512 161.38000488 158.91000366 157.22000122 157.96000671
#  155.80999756 154.52999878 155.96000671 154.46000671 157.36999512
#  163.42999268 153.83999634 155.30999756 152.36999512 150.69999695
#  154.47999573 156.8999939  153.72000122 152.74000549 150.42999268
#  150.77000427 151.75999451 149.83999634 142.47999573 138.19999695
#  142.44999695 146.1000061  146.3999939  145.42999268 140.08999634
#  140.41999817 138.97999573 138.33999634 142.99000549 138.38000488
#  142.41000366 143.75       143.86000061 143.38999939 147.27000427
#  149.44999695 152.33999634 149.3500061  144.80000305 155.74000549
#  153.33999634 150.6499939  145.02999878 138.88000488 138.38000488
#  138.91999817 139.5        134.86999512 146.86999512 149.69999695
#  148.27999878 150.03999329 148.78999329 150.72000122 151.28999329
#  148.00999451 150.17999268 151.07000732 148.11000061 144.22000122
#  141.16999817 148.02999878 148.30999756 147.80999756 146.63000488
#  142.91000366 140.94000244 142.6499939  142.16000366 144.49000549
#  145.47000122 143.21000671 136.5        134.50999451 132.36999512
#  132.30000305 135.44999695 132.22999573 131.86000061 130.02999878
#  126.04000092 129.61000061 129.92999268 125.06999969 126.36000061
#  125.01999664 129.61999512 130.1499939  130.72999573 133.49000549
#  133.41000366 134.75999451 135.94000244 135.21000671 135.27000427
#  137.86999512 141.11000061 142.52999878 141.86000061 143.96000671
#  145.92999268 143.         144.28999329 145.42999268 150.82000732
#  154.5        151.72999573 154.6499939  151.91999817 150.86999512
#  151.00999451 153.8500061  153.19999695 155.33000183 153.71000671
#  152.55000305 148.47999573 148.91000366 149.3999939  146.71000671
#  147.91999817 147.41000366 145.30999756 145.91000366 151.02999878
#  153.83000183 151.6000061  152.86999512 150.58999634 148.5
#  150.47000122 152.58999634 152.99000549 155.8500061  155.
#  157.3999939  159.27999878 157.83000183 158.92999268 160.25      ]
# 12/12 [==============================] - 1s 2ms/step
# Trading strategy predictions:
# Day 1: sell
# Day 2: buy
# Day 3: buy
# Day 4: buy
# Day 5: buy
# Day 6: buy
# Day 7: hold
# Day 8: hold
# Day 9: hold
# Day 10: buy
# Day 11: sell
# Day 12: buy
# Day 13: hold
# Day 14: sell
# Day 15: buy
# Day 16: buy
# Day 17: hold
# Day 18: hold
# Day 19: hold
# Day 20: buy
# Day 21: sell
# Day 22: hold
# Day 23: buy
# Day 24: buy
# Day 25: hold
# Day 26: buy
# Day 27: buy
# Day 28: hold
# Day 29: buy
# Day 30: buy
# Day 31: buy
# Day 32: sell
# Day 33: buy
# Day 34: buy
# Day 35: sell
# Day 36: hold
# Day 37: hold
# Day 38: hold
# Day 39: hold
# Day 40: buy
# Day 41: hold
# Day 42: hold
# Day 43: hold
# Day 44: hold
# Day 45: hold
# Day 46: sell
# Day 47: hold
# Day 48: hold
# Day 49: hold
# Day 50: buy
# Day 51: buy
# Day 52: buy
# Day 53: sell
# Day 54: buy
# Day 55: hold
# Day 56: sell
# Day 57: buy
# Day 58: hold
# Day 59: hold
# Day 60: hold
# Day 61: buy
# Day 62: buy
# Day 63: hold
# Day 64: buy
# Day 65: hold
# Day 66: buy
# Day 67: hold
# Day 68: hold
# Day 69: hold
# Day 70: sell
# Day 71: hold
# Day 72: hold
# Day 73: hold
# Day 74: sell
# Day 75: buy
# Day 76: buy
# Day 77: sell
# Day 78: buy
# Day 79: hold
# Day 80: sell
# Day 81: sell
# Day 82: buy
# Day 83: buy
# Day 84: sell
# Day 85: hold
# Day 86: buy
# Day 87: hold
# Day 88: sell
# Day 89: hold
# Day 90: hold
# Day 91: sell
# Day 92: hold
# Day 93: buy
# Day 94: buy
# Day 95: hold
# Day 96: hold
# Day 97: buy
# Day 98: sell
# Day 99: hold
# Day 100: hold
# Day 101: hold
# Day 102: buy
# Day 103: hold
# Day 104: hold
# Day 105: sell
# Day 106: buy
# Day 107: buy
# Day 108: buy
# Day 109: buy
# Day 110: buy
# Day 111: buy
# Day 112: hold
# Day 113: buy
# Day 114: buy
# Day 115: hold
# Day 116: hold
# Day 117: hold
# Day 118: hold
# Day 119: sell
# Day 120: buy
# Day 121: sell
# Day 122: sell
# Day 123: hold
# Day 124: hold
# Day 125: sell
# Day 126: hold
# Day 127: buy
# Day 128: sell
# Day 129: sell
# Day 130: hold
# Day 131: hold
# Day 132: sell
# Day 133: sell
# Day 134: buy
# Day 135: sell
# Day 136: sell
# Day 137: hold
# Day 138: hold
# Day 139: hold
# Day 140: hold
# Day 141: buy
# Day 142: sell
# Day 143: hold
# Day 144: sell
# Day 145: buy
# Day 146: sell
# Day 147: sell
# Day 148: buy
# Day 149: sell
# Day 150: hold
# Day 151: sell
# Day 152: hold
# Day 153: hold
# Day 154: hold
# Day 155: hold
# Day 156: hold
# Day 157: hold
# Day 158: hold
# Day 159: hold
# Day 160: hold
# Day 161: hold
# Day 162: hold
# Day 163: buy
# Day 164: buy
# Day 165: sell
# Day 166: hold
# Day 167: hold
# Day 168: sell
# Day 169: buy
# Day 170: buy
# Day 171: hold
# Day 172: buy
# Day 173: buy
# Day 174: hold
# Day 175: hold
# Day 176: buy
# Day 177: hold
# Day 178: hold
# Day 179: buy
# Day 180: hold
# Day 181: buy
# Day 182: hold
# Day 183: buy
# Day 184: buy
# Day 185: buy
# Day 186: hold
# Day 187: buy
# Day 188: hold
# Day 189: hold
# Day 190: buy
# Day 191: hold
# Day 192: hold
# Day 193: hold
# Day 194: buy
# Day 195: hold
# Day 196: sell
# Day 197: hold
# Day 198: hold
# Day 199: hold
# Day 200: hold
# Day 201: hold
# Day 202: sell
# Day 203: hold
# Day 204: hold
# Day 205: sell
# Day 206: sell
# Day 207: hold
# Day 208: buy
# Day 209: hold
# Day 210: hold
# Day 211: buy
# Day 212: hold
# Day 213: hold
# Day 214: sell
# Day 215: hold
# Day 216: hold
# Day 217: sell
# Day 218: buy
# Day 219: buy
# Day 220: sell
# Day 221: sell
# Day 222: hold
# Day 223: hold
# Day 224: hold
# Day 225: hold
# Day 226: hold
# Day 227: hold
# Day 228: sell
# Day 229: buy
# Day 230: buy
# Day 231: sell
# Day 232: buy
# Day 233: hold
# Day 234: hold
# Day 235: hold
# Day 236: buy
# Day 237: hold
# Day 238: sell
# Day 239: hold
# Day 240: buy
# Day 241: buy
# Day 242: hold
# Day 243: hold
# Day 244: hold
# Day 245: hold
# Day 246: buy
# Day 247: buy
# Day 248: hold
# Day 249: hold
# Day 250: buy
# Day 251: hold
# Day 252: sell
# Day 253: buy
# Day 254: hold
# Day 255: buy
# Day 256: buy
# Day 257: buy
# Day 258: hold
# Day 259: hold
# Day 260: buy
# Day 261: buy
# Day 262: hold
# Day 263: hold
# Day 264: buy
# Day 265: hold
# Day 266: sell
# Day 267: hold
# Day 268: hold
# Day 269: hold
# Day 270: buy
# Day 271: buy
# Day 272: hold
# Day 273: hold
# Day 274: buy
# Day 275: hold
# Day 276: buy
# Day 277: hold
# Day 278: buy
# Day 279: buy
# Day 280: sell
# Day 281: buy
# Day 282: buy
# Day 283: hold
# Day 284: hold
# Day 285: hold
# Day 286: buy
# Day 287: hold
# Day 288: hold
# Day 289: hold
# Day 290: hold
# Day 291: hold
# Day 292: buy
# Day 293: hold
# Day 294: hold
# Day 295: buy
# Day 296: hold
# Day 297: hold
# Day 298: hold
# Day 299: hold
# Day 300: hold
# Day 301: hold
# Day 302: hold
# Day 303: hold
# Day 304: hold
# Day 305: hold
# Day 306: buy
# Day 307: buy
# Day 308: hold
# Day 309: buy
# Day 310: hold
# Day 311: buy
# Day 312: buy
# Day 313: buy
# Day 314: buy
# Day 315: hold
# Day 316: buy
# Day 317: buy
# Day 318: hold
# Day 319: buy
# Day 320: buy
# Day 321: buy
# Day 322: hold
# Day 323: hold
# Day 324: buy
# Day 325: hold
# Day 326: sell
# Day 327: buy
# Day 328: hold
# Day 329: hold
# Day 330: buy
# Day 331: sell
# Day 332: hold
# Day 333: sell
# Day 334: hold
# Day 335: hold
# Day 336: hold
# Day 337: sell
# Day 338: hold
# Day 339: sell
# Day 340: sell
# Day 341: hold
# Day 342: hold
# Day 343: hold
# Day 344: hold
# Day 345: hold
# Day 346: sell
# Day 347: sell
# Day 348: buy
# Day 349: buy
# Day 350: hold
# Day 351: hold
# Day 352: buy
# Day 353: hold
# Day 354: hold
# Day 355: buy
# Day 356: buy
# Day 357: hold
# Day 358: buy
# Day 359: hold
# Day 360: buy
# Day 361: buy
# Day 362: hold
# Day 363: buy
# Day 364: hold
# Day 365: hold
# Sharpe ratio: 0.0032010433538964965
